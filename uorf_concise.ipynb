# %%
from concise.utils.plot import seqlogo

import numpy as np
import plotseqlogo as plt

# %%
random = np.load('/Users/frederickkorbel/Documents/projects/paper/data/meta/random_data_2000_subset.npy')

# %%
plt.seqlogo_fig(random, vocab='RNA')
# Out:
# /Users/frederickkorbel/anaconda3/envs/mlcis_concise/lib/python3.6/site-packages/descartes/patch.py:65: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   for t in polygon])
# /Users/frederickkorbel/Documents/projects/paper/mlcis/plotseqlogo.py:160: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   ax.set_xticks([],[])

# %%
tenth_percentile = np.load('/Users/frederickkorbel/Documents/projects/paper/data/meta/uorf_10th_percentile.npy')
plt.seqlogo_fig(tenth_percentile, vocab='RNA')
# Out:
# /Users/frederickkorbel/anaconda3/envs/mlcis_concise/lib/python3.6/site-packages/descartes/patch.py:65: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   for t in polygon])
# /Users/frederickkorbel/Documents/projects/paper/mlcis/plotseqlogo.py:160: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   ax.set_xticks([],[])

# %%
ninetyth_percentile = np.load('/Users/frederickkorbel/Documents/projects/paper/data/meta/uorf_90th_percentile.npy')
plt.seqlogo_fig(ninetyth_percentile, vocab='RNA')

# %%
uorf_data = np.load('/Users/frederickkorbel/Documents/projects/paper/data/meta/uorf_data.npy')
plt.seqlogo_fig(uorf_data, vocab='RNA')
# Out:
# /Users/frederickkorbel/anaconda3/envs/mlcis_concise/lib/python3.6/site-packages/descartes/patch.py:65: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   for t in polygon])
# /Users/frederickkorbel/Documents/projects/paper/mlcis/plotseqlogo.py:160: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   ax.set_xticks([],[])
